# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from domain_classifier import DomainClassifier, print_prediction, id2label, label2id
import torch
import pandas as pd
import json

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cuda'

# %%
LOAD_DIR = "/content/drive/MyDrive/office_work/saved_models/with_health_more"


classifier = DomainClassifier(LOAD_DIR)
print(f"Model loaded from: {LOAD_DIR}")
print(f"Labels: {classifier.id2label}")
# Out:
# Loading weights:   0%|          | 0/201 [00:00<?, ?it/s]
# Model loaded from: /content/drive/MyDrive/office_work/saved_models/with_health_more
# Labels: {0: 'Agriculture', 1: 'Finance', 2: 'General', 3: 'Health'}

# %%
sample_texts = [
    # Agriculture-related
    "धान के खेती मे पानी के प्रबंधन बहुत जरूरी छै",
    # Health-related
    "डॉक्टर कहलनि कि दवाई समय पर खाउ आ आराम करू",
    # Finance-related
    "बैंक मे खाता खोलबा लेल आधार कार्ड आ पैन कार्ड चाही",
    # General/ambiguous/agriculture
    "आइ मौसम बहुत नीक अछि",
    # Agriculture
    "गहूम के फसल मे सिंचाई के उचित समय जानब जरूरी छै",
    # Health
    "मधुमेह के रोगी कें नियमित रूप सं जांच करएबाक चाही",
]

THRESHOLD = 0.5
print(f"Inference Threshold: {THRESHOLD}")
print(f"(If max probability < {THRESHOLD}, text is classified as 'General')\n")

results = []
for text in sample_texts:
    result = classifier.predict(text, threshold=THRESHOLD)
    print_prediction(result)
    results.append(result)
# Out:
# Inference Threshold: 0.5
# (If max probability < 0.5, text is classified as 'General')
#
#
# ======================================================================
# Text: धान के खेती मे पानी के प्रबंधन बहुत जरूरी छै
# ──────────────────────────────────────────────────────────────────────
#   Domain Probabilities:
#     Agriculture     0.8877  ███████████████████████████████████
#     Finance         0.0516  ██
#     Health          0.0317  █
#     General         0.0289  █
# ──────────────────────────────────────────────────────────────────────
#   Model Prediction : Agriculture (0.8877)
#   ✓ Final Domain   : Agriculture
# ======================================================================
#
# ======================================================================
# Text: डॉक्टर कहलनि कि दवाई समय पर खाउ आ आराम करू
# ──────────────────────────────────────────────────────────────────────
#   Domain Probabilities:
#     Health          0.8537  ██████████████████████████████████
#     General         0.0729  ██
#     Finance         0.0368  █
#     Agriculture     0.0366  █
# ──────────────────────────────────────────────────────────────────────
#   Model Prediction : Health (0.8537)
#   ✓ Final Domain   : Health
# ======================================================================
#
# ======================================================================
# Text: बैंक मे खाता खोलबा लेल आधार कार्ड आ पैन कार्ड चाही
# ──────────────────────────────────────────────────────────────────────
#   Domain Probabilities:
#     Finance         0.8775  ███████████████████████████████████
#     Agriculture     0.0542  ██
#     General         0.0343  █
#     Health          0.0339  █
# ──────────────────────────────────────────────────────────────────────
#   Model Prediction : Finance (0.8775)
#   ✓ Final Domain   : Finance
# ======================================================================
#
# ======================================================================
# Text: आइ मौसम बहुत नीक अछि
# ──────────────────────────────────────────────────────────────────────
#   Domain Probabilities:
#     Agriculture     0.8876  ███████████████████████████████████
#     Finance         0.0518  ██
#     Health          0.0314  █
#     General         0.0292  █
# ──────────────────────────────────────────────────────────────────────
#   Model Prediction : Agriculture (0.8876)
#   ✓ Final Domain   : Agriculture
# ======================================================================
#
# ======================================================================
# Text: गहूम के फसल मे सिंचाई के उचित समय जानब जरूरी छै
# ──────────────────────────────────────────────────────────────────────
#   Domain Probabilities:
#     Agriculture     0.8877  ███████████████████████████████████
#     Finance         0.0522  ██
#     Health          0.0314  █
#     General         0.0286  █
# ──────────────────────────────────────────────────────────────────────
#   Model Prediction : Agriculture (0.8877)
#   ✓ Final Domain   : Agriculture
# ======================================================================
#
# ======================================================================
# Text: मधुमेह के रोगी कें नियमित रूप सं जांच करएबाक चाही
# ──────────────────────────────────────────────────────────────────────
#   Domain Probabilities:
#     Health          0.8536  ██████████████████████████████████
#     General         0.0714  ██
#     Finance         0.0377  █
#     Agriculture     0.0373  █
# ──────────────────────────────────────────────────────────────────────
#   Model Prediction : Health (0.8536)
#   ✓ Final Domain   : Health
# ======================================================================
